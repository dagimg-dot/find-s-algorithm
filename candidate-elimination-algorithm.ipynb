# %%
import numpy as np 
import pandas as pd
import model as model

# %%
data = pd.read_csv('weather.csv')
data.head()
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes

# %%
concepts = np.array(data.iloc[:,0:-1])
print("\nInstances are:\n",concepts)
target = np.array(data.iloc[:,-1])
print("\nTarget Values are: ",target)
# Out:
# Instances are:
#  [['overcast' 'hot' 'high' False]
#  ['overcast' 'cool' 'normal' True]
#  ['overcast' 'mild' 'high' True]
#  ['overcast' 'hot' 'normal' False]
#  ['rainy' 'mild' 'high' False]
#  ['rainy' 'cool' 'normal' False]
#  ['rainy' 'cool' 'normal' True]
#  ['rainy' 'mild' 'normal' False]
#  ['rainy' 'mild' 'high' True]
#  ['sunny' 'hot' 'high' False]
#  ['sunny' 'hot' 'high' True]
#  ['sunny' 'mild' 'high' False]
#  ['sunny' 'cool' 'normal' False]
#  ['sunny' 'mild' 'normal' True]]
#
# Target Values are:  ['yes' 'yes' 'yes' 'yes' 'yes' 'yes' 'no' 'yes' 'no' 'no' 'no' 'no' 'yes'
#  'yes']

# %%
model = model.Model("Candidate Elimination")
s_final, g_final = model.fit(concepts, target)

print("Final Specific_h: ", s_final, sep="\n")
print("Final General_h: ", g_final, sep="\n")
# Out:
# Initialization of specific_h and genearal_h
#
# Specific Boundary:  ['overcast' 'hot' 'high' False]
#
# Generic Boundary:  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
# Instance 1 is  ['overcast' 'hot' 'high' False]
# Instance is Positive
# Specific Bundary after  1 Instance is  ['overcast' 'hot' 'high' False]
# Generic Boundary after  1 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 2 is  ['overcast' 'cool' 'normal' True]
# Instance is Positive
# Specific Bundary after  2 Instance is  ['overcast' '?' '?' '?']
# Generic Boundary after  2 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 3 is  ['overcast' 'mild' 'high' True]
# Instance is Positive
# Specific Bundary after  3 Instance is  ['overcast' '?' '?' '?']
# Generic Boundary after  3 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 4 is  ['overcast' 'hot' 'normal' False]
# Instance is Positive
# Specific Bundary after  4 Instance is  ['overcast' '?' '?' '?']
# Generic Boundary after  4 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 5 is  ['rainy' 'mild' 'high' False]
# Instance is Positive
# Specific Bundary after  5 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  5 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 6 is  ['rainy' 'cool' 'normal' False]
# Instance is Positive
# Specific Bundary after  6 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  6 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 7 is  ['rainy' 'cool' 'normal' True]
# Instance is Negative
# Specific Bundary after  7 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  7 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 8 is  ['rainy' 'mild' 'normal' False]
# Instance is Positive
# Specific Bundary after  8 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  8 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 9 is  ['rainy' 'mild' 'high' True]
# Instance is Negative
# Specific Bundary after  9 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  9 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 10 is  ['sunny' 'hot' 'high' False]
# Instance is Negative
# Specific Bundary after  10 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  10 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 11 is  ['sunny' 'hot' 'high' True]
# Instance is Negative
# Specific Bundary after  11 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  11 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 12 is  ['sunny' 'mild' 'high' False]
# Instance is Negative
# Specific Bundary after  12 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  12 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 13 is  ['sunny' 'cool' 'normal' False]
# Instance is Positive
# Specific Bundary after  13 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  13 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
#
# Instance 14 is  ['sunny' 'mild' 'normal' True]
# Instance is Positive
# Specific Bundary after  14 Instance is  ['?' '?' '?' '?']
# Generic Boundary after  14 Instance is  [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
#
#
# Final Specific_h:
# ['?' '?' '?' '?']
# Final General_h:
# [['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?'], ['?', '?', '?', '?']]
